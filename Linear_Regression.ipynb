# %% [markdown]
# <a href="https://colab.research.google.com/github/JARIN-TIAS/Algorithm-for-Data-Science/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple Linear Regression**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("//Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = df["YearsExperience"].values
y = df["Salary"].values

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
plt.figure()
plt.grid(True)
plt.plot(x,y,'r.')

# %%
# Independant variable or features
x = x.reshape(-1,1)

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
# Dependant variable or labels
y = y.reshape(-1,1)
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %%
## Seperates the data into test and training sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
## Plotting the training and testing splits
plt.scatter(X_train, y_train, label = "Training Data", color = 'r')
plt.scatter(X_test, y_test, label = "Testing Data", color = 'b')
plt.legend()
plt.grid("True")
plt.title("Test/Train Split")
plt.show()

# %%
# Defining our regressor
regressor = linear_model.LinearRegression()

# %%
# Train the regressor
fit = regressor.fit(X_train, y_train)

# %%
# Returns gradient and intercept
print("Gradient:",fit.coef_)
print("Intercept:",fit.intercept_)
# Out:
# Gradient: [[9397.59296707]]
# Intercept: [25696.67949065]

# %%
# Predicted values
y_pred = regressor.predict(X_test)

# %%
# Plot of the data with the line of best fit
plt.plot(X_test,y_pred)
plt.plot(x,y, "rx")
plt.grid(True)

# %%
#Converts predicted values and test values to a data frame
df = pd.DataFrame({"Predicted": y_pred[:,0], "Actual": y_test[:,0]})
regressor.predict([[20]])
# Out:
# array([[213648.53883211]])

# %%
# Determines a score for our model
score = regressor.score(X_test, y_test)
print(score)
# Out:
# 0.9579051794804535

# %% [markdown]
# **Save and LOad the Model**

# %%
import pickle
filename = '/content/drive/MyDrive/Summer 2022/MSC/Linear_Regression/finalized_model.sav'

# %%
pickle.dump(fit, open(filename, 'wb'))

# %% [markdown]
# **Load Saved Model**

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model.coef_
# Out:
# array([[9249.59691445]])

# %%
loaded_model.intercept_
# Out:
# array([26504.92969961])

# %%
loaded_model.predict([[10]])
# Out:
# array([[46274489.5019462]])

# %% [markdown]
# # **Multiple Linear Regression**
#
# ---

# %%
## Converts advertising csv to a data frame
df = pd.read_csv("//Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
## Independent variables
X = df.drop("Sales",axis=1)

## Dependent variable
y = df["Sales"].values.reshape(-1,1)

# %%
## Splitting into test and training data
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
## Defining regressor
regressor = linear_model.LinearRegression()

# %%
## Training our regressor
fit = regressor.fit(X_train,y_train)

# %%
## Predicting values
y_pred = fit.predict(X_test)

# %%
## Comparing predicted against actual values
df = pd.DataFrame({"Predicted": y_pred[:,0], "Actual": y_test[:,0]})
df
# Out:
#     Predicted  Actual
# 0    6.259012     7.2
# 1   11.299523    11.9
# 2   10.801128     7.3
# 3   14.743626    14.7
# 4   10.142179    10.1
# 5   14.989738    14.9
# 6    8.047676     7.0
# 7    5.715079     8.1
# 8    9.689879    10.9
# 9   16.849133    15.9
# 10   9.948637    11.2
# 11  19.324956    19.6
# 12  12.258347    10.6
# 13   8.816262    10.6
# 14  20.879870    22.4
# 15  11.231902    11.9
# 16  17.634417    18.5
# 17  15.773889    16.0
# 18  10.064103    10.1
# 19  11.304431     8.0
# 20  13.037170    10.8
# 21  18.361618    19.0
# 22  10.028074    11.3
# 23  12.000813    12.2
# 24  21.233179    21.8
# 25  10.621550    12.4
# 26  14.758512    13.6
# 27  13.647898    11.5
# 28  16.452279    16.6
# 29  20.760424    20.8
# 30  17.832515    15.0
# 31  12.551658     9.3
# 32  21.112604    22.6
# 33  19.292335    18.9
# 34  17.318140    17.0
# 35  22.548064    24.7
# 36   3.749907     4.8
# 37  15.031344    15.2
# 38  10.937102     1.6
# 39  15.916031    14.7

# %%
## Plot of the data with the line of best fit
plt.plot(X_test,y_pred)
plt.plot(X,y, "rx")
plt.grid(True)
